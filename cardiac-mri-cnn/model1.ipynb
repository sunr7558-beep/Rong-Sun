# %%
import os
import numpy as np
import pandas as pd
import nibabel as nib
import cv2
from tqdm import tqdm

import mlflow
import mlflow.keras

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import BinaryAccuracy, Precision, Recall

# === Load & Preprocess Data ===
def parse_info_cfg(info_path):
    ed = es = group = None
    with open(info_path, 'r') as f:
        for line in f:
            if "ED:" in line:
                ed = int(line.split(":")[1].strip())
            elif "ES:" in line:
                es = int(line.split(":")[1].strip())
            elif "Group:" in line:
                group = line.split(":")[1].strip()
                if group == "RV":
                    group = "ARV"
    return ed, es, group

def load_mid_slice(path):
    img = nib.load(path).get_fdata()
    mid = img.shape[2] // 2
    return cv2.resize(img[:, :, mid], (128, 128))

def load_tensor(base_path, pid, ed, es):
    ed_img = load_mid_slice(f"{base_path}/{pid}_frame{ed:02d}_gt.nii")
    es_img = load_mid_slice(f"{base_path}/{pid}_frame{es:02d}_gt.nii")
    tensor = np.stack([ed_img, es_img], axis=-1)
    return tensor / np.max(tensor)

def load_dataset_multihead(base_dir):
    X = []
    y_all = {'NOR': [], 'MINF': [], 'DCM': [], 'HCM': [], 'ARV': []}
    classes = list(y_all.keys())

    for patient in tqdm(sorted(os.listdir(base_dir))):
        if not patient.startswith("patient"):
            continue
        try:
            path = os.path.join(base_dir, patient)
            ed, es, group = parse_info_cfg(os.path.join(path, "Info.cfg"))
            tensor = load_tensor(path, patient, ed, es)
            X.append(tensor)

            for cls in classes:
                y_all[cls].append(1 if cls == group else 0)
        except Exception as e:
            print(f" Skipping {patient}: {e}")

    X = np.array(X)
    y_outs = [np.array(y_all[cls]) for cls in classes]
    return X, y_outs, classes

# === Build CNN Multi-Head Model ===
def build_simple_multihead_model(input_shape=(128, 128, 2),
                                 class_names=['NOR', 'MINF', 'DCM', 'HCM', 'ARV'],
                                 learning_rate=0.0004):
    
    inputs = Input(shape=input_shape)

    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D(2)(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D(2)(x)

    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)

    outputs = []
    losses = {}
    metrics = {}

    for cls in class_names:
        head_name = f"{cls}_head"
        head_output = Dense(1, activation='sigmoid', name=head_name)(x)
        outputs.append(head_output)

        losses[head_name] = 'binary_crossentropy'
        metrics[head_name] = [
            BinaryAccuracy(name='accuracy'),
            Precision(name='precision'),
            Recall(name='recall')
        ]

    model = Model(inputs=inputs, outputs=outputs)

    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=losses,
        metrics=metrics
    )

    return model

# === Export Predictions and Compute Accuracy ===
def export_predictions(model, X_test, y_test_list, class_names, output_csv="prediction_results.csv"):
    y_pred_probs = model.predict(X_test)
    y_pred_bin = [(p > 0.5).astype(int).flatten() for p in y_pred_probs]
    y_pred_matrix = np.stack(y_pred_bin, axis=1)
    y_pred_probs_matrix = np.stack([p.flatten() for p in y_pred_probs], axis=1)

    true_class_indices = [
        next(j for j in range(len(class_names)) if y_test_list[j][i] == 1)
        for i in range(len(X_test))
    ]
    true_class_names = [class_names[i] for i in true_class_indices]

    predicted_sets = [
        [class_names[j] for j in range(len(class_names)) if y_pred_matrix[i][j] == 1]
        for i in range(len(X_test))
    ]

    containment_match = [
        true_class_names[i] in predicted_sets[i]
        for i in range(len(X_test))
    ]
    top1_indices = np.argmax(y_pred_probs_matrix, axis=1)
    top1_preds = [class_names[i] for i in top1_indices]
    correct_top1 = [
        top1_preds[i] == true_class_names[i]
        for i in range(len(X_test))
    ]

    patient_ids = sorted([pid for pid in os.listdir('./database/testing') if pid.startswith("patient")])

    df = pd.DataFrame({
        'PatientID': patient_ids,
        'True_Label': true_class_names,
        'Top1_Pred': top1_preds,
        'Predicted_Binary': predicted_sets,
        'Correctly_Contained': containment_match,
        'Correct_Top1': correct_top1
    })

    df.to_csv(output_csv, index=False)
    print(f" Saved predictions to {output_csv}")
    return df, np.mean(correct_top1)

# === Main Execution with Multiple Runs ===
if __name__ == "__main__":
    print("Loading training and testing data...")
    X_train, y_train_list, class_names = load_dataset_multihead('./database/training')
    X_test, y_test_list, _ = load_dataset_multihead('./database/testing')

    mlflow.set_experiment("ACDC_CardiacMRI_Classification")

    target_accuracy = 0.5
    n_trials = 5
    best_accuracy = 0
    best_model = None

    for run_id in range(n_trials):
        print(f"\n=== Run {run_id + 1} ===")
        model = build_simple_multihead_model(
            input_shape=(128, 128, 2),
            class_names=class_names
        )

        with mlflow.start_run(run_name=f"Run_{run_id + 1}"):
            mlflow.log_param("epochs", 200)
            mlflow.log_param("batch_size", 16)
            mlflow.log_param("learning_rate", 0.0004)
            mlflow.log_param("run_id", run_id + 1)

            print("Training model...")
            history = model.fit(
                X_train,
                y_train_list,
                validation_data=(X_test, y_test_list),
                epochs=200,
                batch_size=16,
                verbose=1
            )

            mlflow.keras.log_model(model, "multihead_model")

            print("Predicting and exporting results...")
            df, acc = export_predictions(model, X_test, y_test_list, class_names, 
                                         output_csv=f"prediction_results_run{run_id + 1}.csv")
            mlflow.log_metric("top1_accuracy", acc)

            print(f"Logged accuracy to MLflow: {acc:.3f}")

            if acc > best_accuracy:
                best_accuracy = acc
                best_model = model

            if acc >= target_accuracy:
                print(f" Target accuracy {target_accuracy} achieved at run {run_id + 1}")
                break

    print(f"\n Best accuracy across all runs: {best_accuracy:.3f}")
    if best_model is not None:
        best_model.save("best_multihead_model_above_0.5.h5")
# Out:
# Loading training and testing data...
# 100%|████████████████████████████████████████| 102/102 [00:00<00:00, 252.41it/s]
# 100%|██████████████████████████████████████████| 52/52 [00:00<00:00, 226.13it/s]
# === Run 1 ===
# Training model...
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - ARV_head_accuracy: 0.7964 - ARV_head_loss: 0.5960 - ARV_head_precision: 0.5000 - ARV_head_recall: 0.2262 - DCM_head_accuracy: 0.7402 - DCM_head_loss: 0.6295 - DCM_head_precision: 0.2000 - DCM_head_recall: 0.1124 - HCM_head_accuracy: 0.6925 - HCM_head_loss: 0.6278 - HCM_head_precision: 0.0000e+00 - HCM_head_recall: 0.0000e+00 - MINF_head_accuracy: 0.7060 - MINF_head_loss: 0.6189 - MINF_head_precision: 0.2545 - MINF_head_recall: 0.1888 - NOR_head_accuracy: 0.6832 - NOR_head_loss: 0.6061 - NOR_head_precision: 0.3000 - NOR_head_recall: 0.2686 - loss: 3.0857 - val_ARV_head_accuracy: 0.8000 - val_ARV_head_loss:
- MINF_head_precision: 1.0000 - MINF_head_recall: 0.9253 - NOR_head_accuracy: 0.9554 - NOR_head_loss: 0.1162 - NOR_head_precision: 0.9792 - NOR_head_recall: 0.8210 - loss: 0.3751 - val_ARV_head_accuracy: 0.8600 - val_ARV_head_loss: 0.5488 - val_ARV_head_precision: 0.6667 - val_ARV_head_recall: 0.6000 - val_DCM_head_accuracy: 0.8600 - val_DCM_head_loss: 0.5832 - val_DCM_head_precision: 0.7143 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8200 - val_HCM_head_loss: 0.5371 - val_HCM_head_precision: 0.5714 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.7800 - val_MINF_head_loss: 0.6596 - val_MINF_head_precision: 0.4286 - val_MINF_head_recall: 0.3000 - val_NOR_head_accuracy: 0.7600 - val_NOR_head_loss: 0.6461 - val_NOR_head_precision: 0.4000 - val_NOR_head_recall: 0.4000 - val_loss: 3.3844
# Epoch 29/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 0.0447 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 0.9946 - DCM_head_loss: 0.0230 - DCM_head_precision: 0.9752 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 0.9489 - HCM_head_loss: 0.1234 - HCM_head_precision: 0.8749 - HCM_head_recall: 0.8885 - MINF_head_accuracy: 0.9946 - MINF_head_loss: 0.0512 - MINF_head_precision: 1.0000 - MINF_head_recall: 0.9726 - NOR_head_accuracy: 0.9901 - NOR_head_loss: 0.0663 - NOR_head_precision: 0.9557 - NOR_head_recall: 1.0000 - loss: 0.3030 - val_ARV_head_accuracy: 0.8600 - val_ARV_head_loss: 0.5667 - val_ARV_head_precision: 0.7143 - val_ARV_head_recall: 0.5000 - val_DCM_head_accuracy: 0.8800 - val_DCM_head_loss: 0.7798 - val_DCM_head_precision: 0.8333 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.7800 - val_HCM_head_loss: 0.5243 - val_HCM_head_precision: 0.4444 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.7600 - val_MINF_head_loss: 0.7007 - val_MINF_head_precision: 0.3750 - val_MINF_head_recall: 0.3000 - val_NOR_head_accuracy: 0.7400 - val_NOR_head_loss: 0.6756 - val_NOR_head_precision: 0.3333 - val_NOR_head_recall: 0.3000 - val_loss: 3.5467
# Epoch 30/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 0.0188 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 0.0294 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 0.9802 - HCM_head_loss: 0.0963 - HCM_head_precision: 0.9015 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 1.0000 - MINF_head_loss: 0.0691 - MINF_head_precision: 1.0000 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 1.0000 - NOR_head_loss: 0.0443 - NOR_head_precision: 1.0000 - NOR_head_recall: 1.0000 - loss: 0.2599 - val_ARV_head_accuracy: 0.8400 - val_ARV_head_loss: 0.5878 - val_ARV_head_precision: 0.6667 - val_ARV_head_recall: 0.4000 - val_DCM_head_accuracy: 0.8800 - val_DCM_head_loss: 0.7840 - val_DCM_head_precision: 0.8333 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8000 - val_HCM_head_loss: 0.5637 - val_HCM_head_precision: 0.5000 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.7200 - val_MINF_head_loss: 0.7120 - val_MINF_head_precision: 0.3000 - val_MINF_head_recall: 0.3000 - val_NOR_head_accuracy: 0.7600 - val_NOR_head_loss: 0.7327 - val_NOR_head_precision: 0.2500 - val_NOR_head_recall: 0.1000 - val_loss: 3.6938
# Epoch 31/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - ARV_head_accuracy: 0.9927 - ARV_head_loss: 0.0215 - ARV_head_precision: 0.8401 - ARV_head_recall: 0.8750 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 0.0111 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 0.9946 - HCM_head_loss: 0.0565 - HCM_head_precision: 0.9748 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 0.9962 - MINF_head_loss: 0.0508 - MINF_head_precision: 0.8750 - MINF_head_recall: 0.8556 - NOR_head_accuracy: 1.0000 - NOR_head_loss: 0.0338 - NOR_head_precision: 1.0000 - NOR_head_recall: 1.0000 - loss: 0.1742 - val_ARV_head_accuracy: 0.8600 - val_ARV_head_loss: 0.5894 - val_ARV_head_precision: 0.7143 - val_ARV_head_recall: 0.5000 - val_DCM_head_accuracy: 0.8800 - val_DCM_head_loss: 0.8722 - val_DCM_head_precision: 0.8333 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8200 - val_HCM_head_loss: 0.5977 - val_HCM_head_precision: 0.6000 - val_HCM_head_recall: 0.3000 - val_MINF_head_accuracy: 0.7600 - val_MINF_head_loss: 0.6936 - val_MINF_head_precision: 0.3333 - val_MINF_head_recall: 0.2000 - val_NOR_head_accuracy: 0.7800 - val_NOR_head_loss: 0.7764 - val_NOR_head_precision: 0.4545 - val_NOR_head_recall: 0.5000 - val_loss: 3.8416
# Epoch 32/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 0.0260 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 0.0177 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 0.9746 - HCM_head_loss: 0.0874 - HCM_head_precision: 1.0000 - HCM_head_recall: 0.8460 - MINF_head_accuracy: 0.9946 - MINF_head_loss: 0.0394 - MINF_head_precision: 1.0000 - MINF_head_recall: 0.9740 - NOR_head_accuracy: 0.9975 - NOR_head_loss: 0.0493 - NOR_head_precision: 1.0000 - NOR_head_recall: 0.9875 - loss: 0.2064 - val_ARV_head_accuracy: 0.8400 - val_ARV_head_loss: 0.6215 - val_ARV_head_precision: 0.6667 - val_ARV_head_recall: 0.4000 - val_DCM_head_accuracy: 0.8400 - val_DCM_head_loss: 0.7295 - val_DCM_head_precision: 0.6250 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8200 - val_HCM_head_loss: 0.6060 - val_HCM_head_precision: 0.5714 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.7200 - val_MINF_head_loss: 0.6703 - val_MINF_head_precision: 0.2500 - val_MINF_head_recall: 0.2000 - val_NOR_head_accuracy: 0.7600 - val_NOR_head_loss: 0.7588 - val_NOR_head_precision: 0.4000 - val_NOR_head_recall: 0.4000 - val_loss: 3.7871
# Epoch 33/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - ARV_head_accuracy: 0.9784 - ARV_head_loss: 0.0392 - ARV_head_precision: 1.0000 - ARV_head_recall: 0.8927 - DCM_head_accuracy: 0.9862 - DCM_head_loss: 0.0263 - DCM_head_precision: 0.9244 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 0.9962 - HCM_head_loss: 0.0647 - HCM_head_precision: 0.9818 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 0.9946 - MINF_head_loss: 0.0597 - MINF_head_precision: 0.9740 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 0.9927 - NOR_head_loss: 0.0465 - NOR_head_precision: 0.9678 - NOR_head_recall: 1.0000 - loss: 0.2398 - val_ARV_head_accuracy: 0.8600 - val_ARV_head_loss: 0.6027 - val_ARV_head_precision: 0.6667 - val_ARV_head_recall: 0.6000 - val_DCM_head_accuracy: 0.8800 - val_DCM_head_loss: 0.9719 - val_DCM_head_precision: 0.8333 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.7800 - val_HCM_head_loss: 0.5525 - val_HCM_head_precision: 0.4444 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.7600 - val_MINF_head_loss: 0.6733 - val_MINF_head_precision: 0.3333 - val_MINF_head_recall: 0.2000 - val_NOR_head_accuracy: 0.7800 - val_NOR_head_loss: 0.8503 - val_NOR_head_precision: 0.4545 - val_NOR_head_recall: 0.5000 - val_loss: 3.9094
# Epoch 34/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - ARV_head_accuracy: 0.9862 - ARV_head_loss: 0.0280 - ARV_head_precision: 0.9302 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 0.9893 - DCM_head_loss: 0.0236 - DCM_head_precision: 0.9501 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 0.9901 - HCM_head_loss: 0.0748 - HCM_head_precision: 1.0000 - HCM_head_recall: 0.9580 - MINF_head_accuracy: 0.9808 - MINF_head_loss: 0.0681 - MINF_head_precision: 1.0000 - MINF_head_recall: 0.8875 - NOR_head_accuracy: 0.9802 - NOR_head_loss: 0.0638 - NOR_head_precision: 0.9528 - NOR_head_recall: 0.9528 - loss: 0.2626 - val_ARV_head_accuracy: 0.8200 - val_ARV_head_loss: 0.6116 - val_ARV_head_precision: 0.5714 - val_ARV_head_recall: 0.4000 - val_DCM_head_accuracy: 0.8600 - val_DCM_head_loss: 0.6935 - val_DCM_head_precision: 0.7143 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8200 - val_HCM_head_loss: 0.6151 - val_HCM_head_precision: 0.5714 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.7400 - val_MINF_head_loss: 0.6414 - val_MINF_head_precision: 0.3333 - val_MINF_head_recall: 0.3000 - val_NOR_head_accuracy: 0.7600 - val_NOR_head_loss: 0.8022 - val_NOR_head_precision: 0.3333 - val_NOR_head_recall: 0.2000 - val_loss: 3.8109
# Epoch 35/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 0.0212 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 0.9862 - DCM_head_loss: 0.0282 - DCM_head_precision: 1.0000 - DCM_head_recall: 0.9373 - HCM_head_accuracy: 0.9927 - HCM_head_loss: 0.0666 - HCM_head_precision: 0.9624 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 1.0000 - MINF_head_loss: 0.0437 - MINF_head_precision: 1.0000 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 0.9901 - NOR_head_loss: 0.0352 - NOR_head_precision: 1.0000 - NOR_head_recall: 0.9526 - loss: 0.1973 - val_ARV_head_accuracy: 0.8200 - val_ARV_head_loss: 0.6325 - val_ARV_head_precision: 0.5714 - val_ARV_head_recall: 0.4000 - val_DCM_head_accuracy: 0.8800 - val_DCM_head_loss: 0.7390 - val_DCM_head_precision: 0.8333 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8200 - val_HCM_head_loss: 0.6436 - val_HCM_head_precision: 0.5714 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.7600 - val_MINF_head_loss: 0.6381 - val_MINF_head_precision: 0.3750 - val_MINF_head_recall: 0.3000 - val_NOR_head_accuracy: 0.7600 - val_NOR_head_loss: 0.8062 - val_NOR_head_precision: 0.3333 - val_NOR_head_recall: 0.2000 - val_loss: 3.9282
# Epoch 36/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 0.0193 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 0.0263 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 0.9862 - HCM_head_loss: 0.0371 - HCM_head_precision: 0.8750 - HCM_head_recall: 0.8002 - MINF_head_accuracy: 0.9946 - MINF_head_loss: 0.0538 - MINF_head_precision: 1.0000 - MINF_head_recall: 0.9734 - NOR_head_accuracy: 1.0000 - NOR_head_loss: 0.0135 - NOR_head_precision: 1.0000 - NOR_head_recall: 1.0000 - loss: 0.1522 - val_ARV_head_accuracy: 0.8600 - val_ARV_head_loss: 0.6351 - val_ARV_head_precision: 0.6667 - val_ARV_head_recall: 0.6000 - val_DCM_head_accuracy: 0.8400 - val_DCM_head_loss: 0.6692 - val_DCM_head_precision: 0.6250 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8400 - val_HCM_head_loss: 0.6908 - val_HCM_head_precision: 0.6667 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.7800 - val_MINF_head_loss: 0.6262 - val_MINF_head_precision: 0.4286 - val_MINF_head_recall: 0.3000 - val_NOR_head_accuracy: 0.7600 - val_NOR_head_loss: 0.7940 - val_NOR_head_precision: 0.3750 - val_NOR_head_recall: 0.3000 - val_loss: 3.9888
# Epoch 37/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 0.0124 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 0.0074 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 1.0000 - HCM_head_loss: 0.0430 - HCM_head_precision: 1.0000 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 0.9946 - MINF_head_loss: 0.0607 - MINF_head_precision: 0.9753 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 0.9684 - NOR_head_loss: 0.0483 - NOR_head_precision: 0.7590 - NOR_head_recall: 0.8750 - loss: 0.1702 - val_ARV_head_accuracy: 0.8200 - val_ARV_head_loss: 0.6603 - val_ARV_head_precision: 0.5714 - val_ARV_head_recall: 0.4000 - val_DCM_head_accuracy: 0.8800 - val_DCM_head_loss: 0.8578 - val_DCM_head_precision: 0.8333 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8400 - val_HCM_head_loss: 0.6285 - val_HCM_head_precision: 0.6667 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.7600 - val_MINF_head_loss: 0.6283 - val_MINF_head_precision: 0.3333 - val_MINF_head_recall: 0.2000 - val_NOR_head_accuracy: 0.7600 - val_NOR_head_loss: 0.8331 - val_NOR_head_precision: 0.3750 - val_NOR_head_recall: 0.3000 - val_loss: 4.0761
# Epoch 38/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 0.0115 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 0.0133 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 0.9927 - HCM_head_loss: 0.0536 - HCM_head_precision: 0.9641 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 1.0000 - MINF_head_loss: 0.0311 - MINF_head_precision: 1.0000 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 1.0000 - NOR_head_loss: 0.0176 - NOR_head_precision: 1.0000 - NOR_head_recall: 1.0000 - loss: 0.1299 - val_ARV_head_accuracy: 0.8200 - val_ARV_head_loss: 0.6776 - val_ARV_head_precision: 0.5714 - val_ARV_head_recall: 0.4000 - val_DCM_head_accuracy: 0.8800 - val_DCM_head_loss: 0.8574 - val_DCM_head_precision: 0.8333 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8200 - val_HCM_head_loss: 0.6675 - val_HCM_head_precision: 0.5714 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.7600 - val_MINF_head_loss: 0.6506 - val_MINF_head_precision: 0.3333 - val_MINF_head_recall: 0.2000 - val_NOR_head_accuracy: 0.7200 - val_NOR_head_loss: 0.8926 - val_NOR_head_precision: 0.2500 - val_NOR_head_recall: 0.2000 - val_loss: 4.2776
# Epoch 39/200
# ...
# Epoch 191/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 0.0024 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 3.0035e-04 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 1.0000 - HCM_head_loss: 0.0029 - HCM_head_precision: 1.0000 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 1.0000 - MINF_head_loss: 0.0040 - MINF_head_precision: 1.0000 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 1.0000 - NOR_head_loss: 0.0047 - NOR_head_precision: 1.0000 - NOR_head_recall: 1.0000 - loss: 0.0147 - val_ARV_head_accuracy: 0.8200 - val_ARV_head_loss: 1.0196 - val_ARV_head_precision: 0.5556 - val_ARV_head_recall: 0.5000 - val_DCM_head_accuracy: 0.8600 - val_DCM_head_loss: 1.3881 - val_DCM_head_precision: 0.7143 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8000 - val_HCM_head_loss: 0.9685 - val_HCM_head_precision: 0.5000 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.8400 - val_MINF_head_loss: 1.1492 - val_MINF_head_precision: 0.6250 - val_MINF_head_recall: 0.5000 - val_NOR_head_accuracy: 0.6800 - val_NOR_head_loss: 1.5257 - val_NOR_head_precision: 0.2500 - val_NOR_head_recall: 0.3000 - val_loss: 6.8102
# Epoch 192/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 0.0011 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 7.4337e-04 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 1.0000 - HCM_head_loss: 0.0024 - HCM_head_precision: 1.0000 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 1.0000 - MINF_head_loss: 0.0014 - MINF_head_precision: 1.0000 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 1.0000 - NOR_head_loss: 0.0050 - NOR_head_precision: 1.0000 - NOR_head_recall: 1.0000 - loss: 0.0109 - val_ARV_head_accuracy: 0.8200 - val_ARV_head_loss: 1.0396 - val_ARV_head_precision: 0.5556 - val_ARV_head_recall: 0.5000 - val_DCM_head_accuracy: 0.8400 - val_DCM_head_loss: 1.8111 - val_DCM_head_precision: 0.6667 - val_DCM_head_recall: 0.4000 - val_HCM_head_accuracy: 0.8000 - val_HCM_head_loss: 1.0304 - val_HCM_head_precision: 0.5000 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.8200 - val_MINF_head_loss: 1.2312 - val_MINF_head_precision: 0.5714 - val_MINF_head_recall: 0.4000 - val_NOR_head_accuracy: 0.6800 - val_NOR_head_loss: 1.6708 - val_NOR_head_precision: 0.2500 - val_NOR_head_recall: 0.3000 - val_loss: 7.4230
# Epoch 193/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 6.0486e-04 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 0.0044 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 1.0000 - HCM_head_loss: 0.0023 - HCM_head_precision: 1.0000 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 1.0000 - MINF_head_loss: 0.0024 - MINF_head_precision: 1.0000 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 1.0000 - NOR_head_loss: 8.1876e-04 - NOR_head_precision: 1.0000 - NOR_head_recall: 1.0000 - loss: 0.0107 - val_ARV_head_accuracy: 0.8200 - val_ARV_head_loss: 1.0337 - val_ARV_head_precision: 0.5556 - val_ARV_head_recall: 0.5000 - val_DCM_head_accuracy: 0.8600 - val_DCM_head_loss: 1.4668 - val_DCM_head_precision: 0.7143 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8200 - val_HCM_head_loss: 1.1267 - val_HCM_head_precision: 0.6000 - val_HCM_head_recall: 0.3000 - val_MINF_head_accuracy: 0.8200 - val_MINF_head_loss: 1.2043 - val_MINF_head_precision: 0.5714 - val_MINF_head_recall: 0.4000 - val_NOR_head_accuracy: 0.7000 - val_NOR_head_loss: 1.6417 - val_NOR_head_precision: 0.2727 - val_NOR_head_recall: 0.3000 - val_loss: 7.3427
# Epoch 194/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 2.8064e-04 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 1.9634e-04 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 1.0000 - HCM_head_loss: 0.0024 - HCM_head_precision: 1.0000 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 1.0000 - MINF_head_loss: 6.5270e-04 - MINF_head_precision: 1.0000 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 1.0000 - NOR_head_loss: 6.1489e-04 - NOR_head_precision: 1.0000 - NOR_head_recall: 1.0000 - loss: 0.0042 - val_ARV_head_accuracy: 0.8200 - val_ARV_head_loss: 1.0387 - val_ARV_head_precision: 0.5556 - val_ARV_head_recall: 0.5000 - val_DCM_head_accuracy: 0.8600 - val_DCM_head_loss: 1.3488 - val_DCM_head_precision: 0.7143 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8200 - val_HCM_head_loss: 1.1326 - val_HCM_head_precision: 0.5714 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.8200 - val_MINF_head_loss: 1.1953 - val_MINF_head_precision: 0.5714 - val_MINF_head_recall: 0.4000 - val_NOR_head_accuracy: 0.7200 - val_NOR_head_loss: 1.6385 - val_NOR_head_precision: 0.3000 - val_NOR_head_recall: 0.3000 - val_loss: 7.3015
# Epoch 195/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 0.0077 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 9.7266e-05 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 1.0000 - HCM_head_loss: 0.0059 - HCM_head_precision: 1.0000 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 1.0000 - MINF_head_loss: 8.3153e-04 - MINF_head_precision: 1.0000 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 1.0000 - NOR_head_loss: 0.0048 - NOR_head_precision: 1.0000 - NOR_head_recall: 1.0000 - loss: 0.0199 - val_ARV_head_accuracy: 0.8200 - val_ARV_head_loss: 1.1113 - val_ARV_head_precision: 0.5556 - val_ARV_head_recall: 0.5000 - val_DCM_head_accuracy: 0.8600 - val_DCM_head_loss: 1.5065 - val_DCM_head_precision: 0.7143 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8000 - val_HCM_head_loss: 1.0141 - val_HCM_head_precision: 0.5000 - val_HCM_head_recall: 0.4000 - val_MINF_head_accuracy: 0.8200 - val_MINF_head_loss: 1.2255 - val_MINF_head_precision: 0.5714 - val_MINF_head_recall: 0.4000 - val_NOR_head_accuracy: 0.7200 - val_NOR_head_loss: 1.6369 - val_NOR_head_precision: 0.3000 - val_NOR_head_recall: 0.3000 - val_loss: 7.3822
# Epoch 196/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - ARV_head_accuracy: 0.9927 - ARV_head_loss: 0.0081 - ARV_head_precision: 1.0000 - ARV_head_recall: 0.9580 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 1.3650e-04 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 1.0000 - HCM_head_loss: 0.0031 - HCM_head_precision: 1.0000 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 1.0000 - MINF_head_loss: 4.9736e-04 - MINF_head_precision: 1.0000 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 1.0000 - NOR_head_loss: 4.1400e-04 - NOR_head_precision: 0.8750 - NOR_head_recall: 0.8750 - loss: 0.0127 - val_ARV_head_accuracy: 0.8000 - val_ARV_head_loss: 1.1468 - val_ARV_head_precision: 0.5000 - val_ARV_head_recall: 0.5000 - val_DCM_head_accuracy: 0.8600 - val_DCM_head_loss: 1.4385 - val_DCM_head_precision: 0.7143 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8200 - val_HCM_head_loss: 0.9722 - val_HCM_head_precision: 0.5556 - val_HCM_head_recall: 0.5000 - val_MINF_head_accuracy: 0.8200 - val_MINF_head_loss: 1.2361 - val_MINF_head_precision: 0.5714 - val_MINF_head_recall: 0.4000 - val_NOR_head_accuracy: 0.7400 - val_NOR_head_loss: 1.6280 - val_NOR_head_precision: 0.2857 - val_NOR_head_recall: 0.2000 - val_loss: 7.3722
# Epoch 197/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 0.0097 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 0.0023 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 1.0000 - HCM_head_loss: 5.8003e-04 - HCM_head_precision: 0.8750 - HCM_head_recall: 0.8750 - MINF_head_accuracy: 1.0000 - MINF_head_loss: 6.5801e-04 - MINF_head_precision: 1.0000 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 0.9927 - NOR_head_loss: 0.0129 - NOR_head_precision: 1.0000 - NOR_head_recall: 0.9646 - loss: 0.0267 - val_ARV_head_accuracy: 0.8200 - val_ARV_head_loss: 1.2034 - val_ARV_head_precision: 0.5556 - val_ARV_head_recall: 0.5000 - val_DCM_head_accuracy: 0.8600 - val_DCM_head_loss: 1.5837 - val_DCM_head_precision: 0.7143 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8400 - val_HCM_head_loss: 0.9587 - val_HCM_head_precision: 0.6250 - val_HCM_head_recall: 0.5000 - val_MINF_head_accuracy: 0.8200 - val_MINF_head_loss: 1.2695 - val_MINF_head_precision: 0.5714 - val_MINF_head_recall: 0.4000 - val_NOR_head_accuracy: 0.7000 - val_NOR_head_loss: 1.6783 - val_NOR_head_precision: 0.2727 - val_NOR_head_recall: 0.3000 - val_loss: 7.6069
# Epoch 198/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 4.0891e-04 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 2.0853e-04 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 1.0000 - HCM_head_loss: 0.0071 - HCM_head_precision: 1.0000 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 1.0000 - MINF_head_loss: 3.6937e-04 - MINF_head_precision: 1.0000 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 1.0000 - NOR_head_loss: 0.0014 - NOR_head_precision: 1.0000 - NOR_head_recall: 1.0000 - loss: 0.0098 - val_ARV_head_accuracy: 0.8200 - val_ARV_head_loss: 1.2472 - val_ARV_head_precision: 0.5556 - val_ARV_head_recall: 0.5000 - val_DCM_head_accuracy: 0.8600 - val_DCM_head_loss: 1.6613 - val_DCM_head_precision: 0.7143 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8000 - val_HCM_head_loss: 0.8871 - val_HCM_head_precision: 0.5000 - val_HCM_head_recall: 0.5000 - val_MINF_head_accuracy: 0.8000 - val_MINF_head_loss: 1.3461 - val_MINF_head_precision: 0.5000 - val_MINF_head_recall: 0.3000 - val_NOR_head_accuracy: 0.6800 - val_NOR_head_loss: 1.8200 - val_NOR_head_precision: 0.2500 - val_NOR_head_recall: 0.3000 - val_loss: 7.8827
# Epoch 199/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 0.0014 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 1.2501e-04 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 1.0000 - HCM_head_loss: 0.0071 - HCM_head_precision: 1.0000 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 1.0000 - MINF_head_loss: 7.0534e-04 - MINF_head_precision: 1.0000 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 1.0000 - NOR_head_loss: 0.0127 - NOR_head_precision: 1.0000 - NOR_head_recall: 1.0000 - loss: 0.0219 - val_ARV_head_accuracy: 0.8000 - val_ARV_head_loss: 1.2085 - val_ARV_head_precision: 0.5000 - val_ARV_head_recall: 0.5000 - val_DCM_head_accuracy: 0.8600 - val_DCM_head_loss: 1.5303 - val_DCM_head_precision: 0.7143 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.7800 - val_HCM_head_loss: 0.8750 - val_HCM_head_precision: 0.4615 - val_HCM_head_recall: 0.6000 - val_MINF_head_accuracy: 0.8000 - val_MINF_head_loss: 1.3189 - val_MINF_head_precision: 0.5000 - val_MINF_head_recall: 0.3000 - val_NOR_head_accuracy: 0.7200 - val_NOR_head_loss: 1.6982 - val_NOR_head_precision: 0.3000 - val_NOR_head_recall: 0.3000 - val_loss: 7.5811
# Epoch 200/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - ARV_head_accuracy: 1.0000 - ARV_head_loss: 0.0032 - ARV_head_precision: 1.0000 - ARV_head_recall: 1.0000 - DCM_head_accuracy: 1.0000 - DCM_head_loss: 3.5176e-04 - DCM_head_precision: 1.0000 - DCM_head_recall: 1.0000 - HCM_head_accuracy: 1.0000 - HCM_head_loss: 0.0025 - HCM_head_precision: 1.0000 - HCM_head_recall: 1.0000 - MINF_head_accuracy: 1.0000 - MINF_head_loss: 6.4638e-04 - MINF_head_precision: 1.0000 - MINF_head_recall: 1.0000 - NOR_head_accuracy: 1.0000 - NOR_head_loss: 0.0024 - NOR_head_precision: 1.0000 - NOR_head_recall: 1.0000 - loss: 0.0095 - val_ARV_head_accuracy: 0.8000 - val_ARV_head_loss: 1.1880 - val_ARV_head_precision: 0.5000 - val_ARV_head_recall: 0.5000 - val_DCM_head_accuracy: 0.8600 - val_DCM_head_loss: 1.3118 - val_DCM_head_precision: 0.7143 - val_DCM_head_recall: 0.5000 - val_HCM_head_accuracy: 0.8000 - val_HCM_head_loss: 0.8439 - val_HCM_head_precision: 0.5000 - val_HCM_head_recall: 0.5000 - val_MINF_head_accuracy: 0.8000 - val_MINF_head_loss: 1.2653 - val_MINF_head_precision: 0.5000 - val_MINF_head_recall: 0.4000 - val_NOR_head_accuracy: 0.7400 - val_NOR_head_loss: 1.6506 - val_NOR_head_precision: 0.2857 - val_NOR_head_recall: 0.2000 - val_loss: 7.3017
# 2025/05/03 01:36:12 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2025/05/03 01:36:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Predicting and exporting results...
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x36c847e20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/stepWARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x36c847e20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#  Saved predictions to prediction_results_run3.csv
# Logged accuracy to MLflow: 0.520
# 🎯 Target accuracy 0.5 achieved at run 3
#
# ✅ Best accuracy across all runs: 0.520

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import mlflow
import os

# === Load Saved Predictions ===
prediction_csv = "prediction_results_run3.csv"  # 🔁 Update this if needed
df = pd.read_csv(prediction_csv)

# === Define Class Names ===
class_names = ['NOR', 'MINF', 'DCM', 'HCM', 'ARV']

# === Convert Labels to Indices ===
true_labels = df['True_Label'].map({cls: i for i, cls in enumerate(class_names)})
pred_labels = df['Top1_Pred'].map({cls: i for i, cls in enumerate(class_names)})

# === Confusion Matrix ===
cm = confusion_matrix(true_labels, pred_labels)
cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)

# === Save Confusion Matrix Plot ===
plt.figure(figsize=(8, 6))
sns.heatmap(cm_df, annot=True, fmt='d', cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()

confusion_path = "confusion_matrix_run3.png"
plt.savefig(confusion_path)
plt.close()

# === Log confusion matrix to MLflow ===
mlflow.log_artifact(confusion_path)

# === Classification Report ===
report = classification_report(true_labels, pred_labels, target_names=class_names, output_dict=True)
report_df = pd.DataFrame(report).transpose()
report_df[['precision', 'recall', 'f1-score']] = report_df[['precision', 'recall', 'f1-score']].round(3)

# Save and log report
report_path = "classification_report_run3.csv"
report_df.to_csv(report_path)
mlflow.log_artifact(report_path)

# === Log overall accuracy separately ===
accuracy = report['accuracy']
mlflow.log_metric("overall_accuracy_run3", accuracy)

# === Console Output (optional) ===
print("\nConfusion Matrix:")
print(cm_df)

print("\nClassification Report:")
print(report_df[['precision', 'recall', 'f1-score', 'support']])
print(f"\nOverall Accuracy: {accuracy:.3f}")
# Out:
# Confusion Matrix:
#       NOR  MINF  DCM  HCM  ARV
# NOR     2     2    0    2    4
# MINF    3     5    1    1    0
# DCM     1     2    6    0    1
# HCM     1     0    0    7    2
# ARV     2     0    1    1    6
#
# Classification Report:
#               precision  recall  f1-score  support
# NOR               0.222    0.20     0.211    10.00
# MINF              0.556    0.50     0.526    10.00
# DCM               0.750    0.60     0.667    10.00
# HCM               0.636    0.70     0.667    10.00
# ARV               0.462    0.60     0.522    10.00
# accuracy          0.520    0.52     0.520     0.52
# macro avg         0.525    0.52     0.518    50.00
# weighted avg      0.525    0.52     0.518    50.00
#
# Overall Accuracy: 0.520

# %%
from tensorflow.keras.models import Model
from tf_keras_vis.gradcam import Gradcam
from tf_keras_vis.utils.model_modifiers import ReplaceToLinear
import matplotlib.pyplot as plt
import numpy as np
import os

# === Setup Output Folder ===
os.makedirs("gradcam_outputs_run3", exist_ok=True)

# === Define Class Names ===
class_names = ['NOR', 'MINF', 'DCM', 'HCM', 'ARV']

# === Choose a Sample (e.g., first sample) ===
sample_index = 0
sample = X_test[sample_index:sample_index+1]  # shape (1, 128, 128, 2)

# === Loop through All Heads ===
for class_idx, class_name in enumerate(class_names):
    print(f"Generating Grad-CAM for class: {class_name}...")

    # --- Extract single-head submodel ---
    target_head_name = model.output_names[class_idx]
    submodel = Model(inputs=model.input, outputs=model.get_layer(target_head_name).output)

    # --- Score function (identity) ---
    def score_fn(output):
        return output

    # --- Init GradCAM ---
    gradcam = Gradcam(submodel, model_modifier=ReplaceToLinear(), clone=True)

    # --- Generate heatmap ---
    cam = gradcam(score_fn, sample, penultimate_layer=-1)

    # --- Plot ED slice with Grad-CAM overlay ---
    plt.figure(figsize=(4, 4))
    plt.imshow(sample[0][:, :, 0], cmap='gray')         # ED slice
    plt.imshow(cam[0], cmap='jet', alpha=0.5)           # Overlay CAM
    plt.title(f"Grad-CAM - {class_name}")
    plt.axis('off')
    plt.tight_layout()

    # --- Save plot ---
    save_path = f"gradcam_outputs_run3/gradcam_{class_name}_run3.png"
    plt.savefig(save_path)
    plt.close()
    print(f"Saved Grad-CAM for {class_name} to {save_path}")
# Out:
# Generating Grad-CAM for class: NOR...
# Saved Grad-CAM for NOR to gradcam_outputs_run3/gradcam_NOR_run3.png
# Generating Grad-CAM for class: MINF...
# Saved Grad-CAM for MINF to gradcam_outputs_run3/gradcam_MINF_run3.png
# Generating Grad-CAM for class: DCM...
# Saved Grad-CAM for DCM to gradcam_outputs_run3/gradcam_DCM_run3.png
# Generating Grad-CAM for class: HCM...
# Saved Grad-CAM for HCM to gradcam_outputs_run3/gradcam_HCM_run3.png
# Generating Grad-CAM for class: ARV...
# Saved Grad-CAM for ARV to gradcam_outputs_run3/gradcam_ARV_run3.png

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os

# === Create Folder for Output ===
os.makedirs("saliency_outputs_run3", exist_ok=True)

# === Class Names ===
class_names = ['NOR', 'MINF', 'DCM', 'HCM', 'ARV']

# === Select a Test Sample (e.g., first sample) ===
sample_index = 0
input_image = X_test[sample_index:sample_index+1]  # shape: (1, 128, 128, 2)

# === Loop Through Each Class Head ===
for class_idx, class_name in enumerate(class_names):
    print(f"Generating saliency map for class: {class_name}...")

    # --- Extract Head Submodel ---
    head_name = model.output_names[class_idx]
    submodel = tf.keras.Model(inputs=model.input, outputs=model.get_layer(head_name).output)

    # --- Track Gradients ---
    input_tensor = tf.convert_to_tensor(input_image)
    with tf.GradientTape() as tape:
        tape.watch(input_tensor)
        predictions = submodel(input_tensor)
        output = predictions[:, 0]  # scalar value

    # --- Compute Gradient w.r.t. Input ---
    grads = tape.gradient(output, input_tensor)[0]  # shape: (128, 128, 2)

    # --- Channel-wise Max Absolute Gradient (ED & ES) ---
    saliency = np.max(np.abs(grads), axis=-1)

    # --- Normalize for Visualization ---
    saliency = (saliency - saliency.min()) / (saliency.max() - saliency.min() + 1e-8)

    # --- Plot Overlay on ED Slice ---
    plt.figure(figsize=(4, 4))
    plt.imshow(input_image[0][:, :, 0], cmap='gray')     # ED slice
    plt.imshow(saliency, cmap='hot', alpha=0.5)
    plt.title(f"Saliency Map - {class_name}")
    plt.axis('off')
    plt.tight_layout()

    # --- Save Output ---
    save_path = f"saliency_outputs_run3/saliency_{class_name}_run3.png"
    plt.savefig(save_path)
    plt.close()
    print(f"Saved: {save_path}")
# Out:
# Generating saliency map for class: NOR...
# Saved: saliency_outputs_run3/saliency_NOR_run3.png
# Generating saliency map for class: MINF...
# Saved: saliency_outputs_run3/saliency_MINF_run3.png
# Generating saliency map for class: DCM...
# Saved: saliency_outputs_run3/saliency_DCM_run3.png
# Generating saliency map for class: HCM...
# Saved: saliency_outputs_run3/saliency_HCM_run3.png
# Generating saliency map for class: ARV...
# Saved: saliency_outputs_run3/saliency_ARV_run3.png

# %%
def export_predictions(model, X_test, y_test_list, class_names, output_csv="prediction_results.csv", prob_output="y_pred_probs_run3.npy"):
    y_pred_probs = model.predict(X_test)
    y_pred_bin = [(p > 0.5).astype(int).flatten() for p in y_pred_probs]
    y_pred_matrix = np.stack(y_pred_bin, axis=1)
    y_pred_probs_matrix = np.stack([p.flatten() for p in y_pred_probs], axis=1)

    # Save predicted probability matrix for ROC
    np.save(prob_output, y_pred_probs_matrix)

    true_class_indices = [
        next(j for j in range(len(class_names)) if y_test_list[j][i] == 1)
        for i in range(len(X_test))
    ]
    true_class_names = [class_names[i] for i in true_class_indices]

    predicted_sets = [
        [class_names[j] for j in range(len(class_names)) if y_pred_matrix[i][j] == 1]
        for i in range(len(X_test))
    ]

    containment_match = [
        true_class_names[i] in predicted_sets[i]
        for i in range(len(X_test))
    ]
    top1_indices = np.argmax(y_pred_probs_matrix, axis=1)
    top1_preds = [class_names[i] for i in top1_indices]
    correct_top1 = [
        top1_preds[i] == true_class_names[i]
        for i in range(len(X_test))
    ]

    patient_ids = sorted([pid for pid in os.listdir('./database/testing') if pid.startswith("patient")])

    df = pd.DataFrame({
        'PatientID': patient_ids,
        'True_Label': true_class_names,
        'Top1_Pred': top1_preds,
        'Predicted_Binary': predicted_sets,
        'Correctly_Contained': containment_match,
        'Correct_Top1': correct_top1
    })

    df.to_csv(output_csv, index=False)
    print(f" Saved predictions to {output_csv}")
    print(f" Saved prediction probabilities to {prob_output}")
    return df, np.mean(correct_top1)

# %%
df, acc = export_predictions(model, X_test, y_test_list, class_names,
                             output_csv="prediction_results_run3.csv",
                             prob_output="y_pred_probs_run3.npy")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  Saved predictions to prediction_results_run3.csv
#  Saved prediction probabilities to y_pred_probs_run3.npy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import mlflow

# === Load prediction CSV from run 3 ===
df = pd.read_csv("prediction_results_run3.csv")

# === Define class names and binarize labels ===
class_names = ['NOR', 'MINF', 'DCM', 'HCM', 'ARV']
n_classes = len(class_names)

# Map labels to indices
label_to_index = {cls: i for i, cls in enumerate(class_names)}
true_labels = df['True_Label'].map(label_to_index).values
y_true = label_binarize(true_labels, classes=range(n_classes))

# Load prediction probabilities for each class
# Assuming you saved predicted probabilities earlier as a CSV or you have access via inference
# If not yet available, modify your export_predictions function to save `y_pred_probs_matrix`
y_pred_probs = np.load("y_pred_probs_run3.npy")  # Shape: (n_samples, 5)

# === Compute ROC curve and AUC ===
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# === Plot ROC Curve for all classes ===
plt.figure(figsize=(8, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'{class_names[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random Chance')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multi-Head CNN')
plt.legend(loc='lower right')
plt.tight_layout()
plt.savefig("roc_curve_multihead_run3.png")
plt.close()

# === Log AUC and ROC plot ===
for i in range(n_classes):
    mlflow.log_metric(f"AUC_{class_names[i]}", roc_auc[i])
mlflow.log_artifact("roc_curve_multihead_run3.png")

print("ROC curves and AUC scores logged to MLflow.")
# Out:
# ROC curves and AUC scores logged to MLflow.
